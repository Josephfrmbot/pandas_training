# %% [markdown]
# # Import librairies

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read csv

# %%
df = pd.read_csv('imdb_top_1000.csv')
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime   Genre  \
# 0    The Shawshank Redemption          1994           A  142 min   Drama
# 1               The Godfather          1972           A  175 min   Crime
# 2             The Dark Knight          2008          UA  152 min  Action
# ...

# %% [markdown]
# # Information about the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    1000 non-null   object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          1000 non-null   int64
# dtypes: float64(2), int64(2), object(12)
# memory usage: 125.1+ KB

# %% [markdown]
# # Selecting the columns we need

# %%
df= df[['Series_Title','Genre','IMDB_Rating','Star1','Star2','Star3','Star4','Director','Gross']]
df.head(5)
# Out:
#                Series_Title   Genre  IMDB_Rating           Star1  \
# 0  The Shawshank Redemption   Drama          9.3     Tim Robbins
# 1             The Godfather   Crime          9.2   Marlon Brando
# 2           The Dark Knight  Action          9.0  Christian Bale
# 3    The Godfather: Part II   Crime          9.0       Al Pacino
# 4              12 Angry Men   Crime          9.0     Henry Fonda
#
#             Star2          Star3           Star4              Director  \
# 0  Morgan Freeman     Bob Gunton  William Sadler        Frank Darabont
# 1       Al Pacino     James Caan    Diane Keaton  Francis Ford Coppola
# 2    Heath Ledger  Aaron Eckhart   Michael Caine     Christopher Nolan
# 3  Robert De Niro  Robert Duvall    Diane Keaton  Francis Ford Coppola
# 4     Lee J. Cobb  Martin Balsam    John Fiedler          Sidney Lumet
#
#        Gross
# 0   28341469
# 1  134966411
# 2  534858444
# 3   57300000
# 4    4360000

# %% [markdown]
# # Counting the titles

# %%
df['Series_Title'].value_counts()
# Out:
# Drishyam                    2
# The Shawshank Redemption    1
# Awakenings                  1
# Tombstone                   1
# The Sandlot                 1
#                            ..
# Guardians of the Galaxy     1
# Blade Runner 2049           1
# Her                         1
# Bohemian Rhapsody           1
# The 39 Steps                1
# Name: Series_Title, Length: 999, dtype: int64

# %% [markdown]
# # Counting the genre in the ranking

# %%
df ['Genre'].value_counts()
# Out:
# Drama        289
# Action       172
# Comedy       155
# Crime        107
# Biography     88
# Animation     82
# Adventure     72
# Mystery       12
# Horror        11
# Western        4
# Film-Noir      3
# Fantasy        2
# Family         2
# Thriller       1
# Name: Genre, dtype: int64

# %% [markdown]
# # Who is the star with the most leading roles ?

# %%
df['Star1'].value_counts()
# Out:
# Tom Hanks          12
# Robert De Niro     11
# Al Pacino          10
# Clint Eastwood     10
# Humphrey Bogart     9
#                    ..
# Preity Zinta        1
# Javier Bardem       1
# Ki-duk Kim          1
# Vladimir Garin      1
# Robert Donat        1
# Name: Star1, Length: 660, dtype: int64

# %% [markdown]
# # Who is the star with the most second roles ?

# %%
df['Star2'].value_counts()
# Out:
# Emma Watson          7
# Matt Damon           5
# Kate Winslet         4
# Ian McKellen         4
# Chris Evans          4
#                     ..
# Viola Davis          1
# Morena Baccarin      1
# Shahab Hosseini      1
# Simon Yam            1
# Madeleine Carroll    1
# Name: Star2, Length: 841, dtype: int64

# %% [markdown]
# # What are the movies rated  a 9.0 ?

# %%
fil = df['Star1'] == 'Denzel Washington'
df[fil]
df.loc[fil, 'Series_Title' ]
# Out:
# 622      American Gangster
# 644    Remember the Titans
# 782            Man on Fire
# 802           Training Day
# 820              Malcolm X
# 921             Inside Man
# 952          The Hurricane
# Name: Series_Title, dtype: object

# %% [markdown]
# # Checking how many times D. W has been mentionned

# %%
df.isin(['Denzel Washington']).any()
# Out:
# Series_Title    False
# Genre           False
# IMDB_Rating     False
# Star1            True
# Star2            True
# Star3           False
# Star4           False
# Director        False
# Gross           False
# dtype: bool

# %% [markdown]
# # Getting all the movies where here acted

# %% [markdown]
# df.isin(['Denzel Washington']).any()

# %%
df= df[df.isin(['Denzel Washington']).any(1)]
df
# Out:
#             Series_Title      Genre IMDB_Rating              Star1  \
# 622    American Gangster  Biography           9  Denzel Washington
# 644  Remember the Titans  Biography           9  Denzel Washington
# 673                Glory  Biography           9  Matthew Broderick
# 782          Man on Fire     Action           9  Denzel Washington
# 802         Training Day      Crime           9  Denzel Washington
# 818         Philadelphia      Drama           9          Tom Hanks
# 820            Malcolm X  Biography           9  Denzel Washington
# 921           Inside Man      Crime           9  Denzel Washington
# 952        The Hurricane  Biography           9  Denzel Washington
#
#                   Star2               Star3                Star4  \
# 622       Russell Crowe    Chiwetel Ejiofor          Josh Brolin
# 644         Will Patton         Wood Harris           Ryan Hurst
# 673   Denzel Washington          Cary Elwes       Morgan Freeman
# ...

# %% [markdown]
# # In which genre he's played the most ?

# %%
df.loc[df.isin(['Denzel Washington']).any(1),'Genre']
# Out:
# 622    Biography
# 644    Biography
# 673    Biography
# 782       Action
# 802        Crime
# 818        Drama
# 820    Biography
# 921        Crime
# 952    Biography
# Name: Genre, dtype: object

# %% [markdown]
# # How many times

# %%
df.loc[df.isin(['Denzel Washington']).any(1),'Genre'].value_counts()

# %% [markdown]
# # Count Tom Hanks an Denzel Washington movie

# %%
df[df['Star1'].isin(['Tom Hanks','Denzel Washington'])]
# Out:
#             Series_Title      Genre IMDB_Rating              Star1  \
# 622    American Gangster  Biography           9  Denzel Washington
# 644  Remember the Titans  Biography           9  Denzel Washington
# 782          Man on Fire     Action           9  Denzel Washington
# 802         Training Day      Crime           9  Denzel Washington
# 818         Philadelphia      Drama           9          Tom Hanks
# 820            Malcolm X  Biography           9  Denzel Washington
# 921           Inside Man      Crime           9  Denzel Washington
# 952        The Hurricane  Biography           9  Denzel Washington
#
#                   Star2               Star3                Star4  \
# 622       Russell Crowe    Chiwetel Ejiofor          Josh Brolin
# 644         Will Patton         Wood Harris           Ryan Hurst
# 782  Christopher Walken      Dakota Fanning       Radha Mitchell
# 802         Ethan Hawke         Scott Glenn         Tom Berenger
# ...

# %% [markdown]
# # Group by director

# %%
 director = df.groupby(['Director'])

# %%
director.get_group('Spike Lee')
# Out:
#     Series_Title      Genre IMDB_Rating              Star1           Star2  \
# 820    Malcolm X  Biography           9  Denzel Washington  Angela Bassett
# 921   Inside Man      Crime           9  Denzel Washington      Clive Owen
#
#             Star3                Star4   Director     Gross
# 820  Delroy Lindo            Spike Lee  Spike Lee  48169908
# 921  Jodie Foster  Christopher Plummer  Spike Lee  88513495

# %%
print(df_director)
